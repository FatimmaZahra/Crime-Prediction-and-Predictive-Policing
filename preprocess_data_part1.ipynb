# %% [markdown]
# # ACTA 3. Preprocesado de los datos

# %% [markdown]
# ## Índice
# - [Introducción](#Introducción)
# - [Cálculo de variables](#Cálulo-de-variables)
#     - [Neighborhood](#Cálulo-de-variables#Neighborhood)
#     - [Police_district](#Cálulo-de-variables#Police_district)
#     - [Holiday](#Cálulo-de-variables#Holiday)
#     - [Street](#Cálulo-de-variables#Street)
# - [Ejecución Paralela del Procesado](#Ejecución-Paralela-del-Procesado)

# %% [markdown]
# ## Introducción<a name="Introducción"></a>

# %% [markdown]
# El propósito de esta parte del proyecto es el de preparar nuestra base de datos para poder emplearla para la obtención de nuestro modelo de datos.
# Para conseguir nuestro objetivo dividiremos esta etapa en dos, la primera consistirá en el cálculo de nuevas variables para lo que se empleará este archivo y  la segunda parte  comprenserá una limpieza de todos los datos obtenidos a partir de la unión de los incidentes limpios y el cálculo de estas nuevas variables. Posteriormente en la segunda parte también se aplicará la codificación de las variables categóricas para convertirlas en variables numéricas y de esta forma poder emplearlas en un futuro en caso de que apliquemos alguna téncica estadística que requiera datos numéricos.
#
# Para comenzar con nuestra primera parte cargaremos nuestro conjunto de datos resultante de la limpieza de datos.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import json
from shapely.geometry import Point, shape
import geopandas as gpd
import urllib.request
import numpy as np
import holidays
from geopy.geocoders import Nominatim
import concurrent.futures
import time

# %%
Incidents_c = pd.read_csv('Incidents_Clean_F.csv', delimiter = ',')
Incidents_c.columns
# Out:
# Index(['incident_datetime', 'incident_day_of_week', 'incident_code',
#        'incident_category', 'incident_subcategory', 'resolution', 'latitude',
#        'longitude'],
#       dtype='object')

# %% [markdown]
# ## Cálculo de variables<a name="Cálculo de variables"></a>

# %% [markdown]
# ### Neighborhood <a name="Neighborhood"></a>

# %% [markdown]
# Para calcular la variable vecindario lo que haremos será crear una función que a partir del conjunto de datos de vecindarios de San Francisco en el que se defínen los polígonos de cada vecindario, localice a qué vecindario pertenece cada uno de nuestros registros a partir de la latitud y la longitud.
# La descarga de este archivo se puede ver en el documento "ACTA 1. Obtención y extracción de los datos".

# %%
#VECINDARIO
def assign_neighborhood(df, geojson_url):
    filename = 'neighborhoods.geojson'
    urllib.request.urlretrieve(geojson_url, filename)

    neighborhoods = gpd.read_file('neighborhoods.geojson')

    geometry = [Point(xy) for xy in zip(df['longitude'], df['latitude'])]
    crs = {'init': 'epsg:4326'}
    incidents_geo = gpd.GeoDataFrame(df, crs=crs, geometry=geometry)

    result = gpd.sjoin(incidents_geo, neighborhoods, how="left", op='intersects')

    return result['neighborhoods_analysis_boundaries']

# %% [markdown]
# ### Police_district <a name="Police_district"></a>

# %% [markdown]
# Calcularemos también el distrito policial al que pertenece cada uno de nuestros registros a partir del conjunto de datos Police Districs descargado en el documento "ACTA 1. Obtención y extracción de los datos".
# Para ello crearemos una función y buscaremos cada registro en los distintos polígonos que define el archivo y en cuanto coincida devolverá el nombre del distrito.

# %%
#DISTRITO POLICIAL

file_path = 'Current Police Districts.geojson'

with open(file_path) as f:
    js = json.load(f)
    districts = [{'name': feature['properties']['district'], 'geometry': shape(feature['geometry'])} for feature in js['features']]

def is_in_district(latitude, longitude):
    point = Point(longitude, latitude)
    for district in districts:
        if point.within(district['geometry']):
            return district['name']
    return None

# %% [markdown]
# ### Holiday <a name="Holiday"></a>

# %% [markdown]
# También calcularemos la columna Holiday que nos determinará si el incidente analizada s eha producido en un día festivo en San Francisco o en California o en Ambos.
# Para ello emplearemos la librería holidays y cargaremos los días festivos desde 2018 hasta 2023 y veremos si coincide con la fecha de nuestro incidente.

# %%
#FESTIVO

ca_holidays = holidays.US(state='CA')
sf_holidays = holidays.US(state='CA', years=range(2018, 2024))


def is_holiday(date):
    if date in ca_holidays and date in sf_holidays:
        return "Both"
    elif date in ca_holidays:
        return "California"
    elif date in sf_holidays:
        return "San Francisco"
    else:
        return "None"

# %% [markdown]
# ### Street <a name="Street"></a>

# %% [markdown]
# Por último, calcularemos la columna Street que nos determinará la calle en la que se ha producido el incidente. Para ello crearemos una función que empleará la librería Nominatim que devolverá la calle a partir de la latitud y la longitud.

# %%
#CALLE
geolocator = Nominatim(user_agent='myGeocoder')

def get_street(longitude, latitude):
    try:
        location = geolocator.reverse((latitude, longitude), timeout=10)
        time.sleep(1)
        street = location.raw['address']['road'] if 'road' in location.raw['address'] else None
        print(f"Obtenido: {street}")
        return street
    except Exception as e:
        print(f"Error al obtener la dirección: {e}")
        return 'No calculado'

# %% [markdown]
# ## Ejecución Paralela del Procesado<a name="Ejecución Paralela del Procesado"></a>

# %% [markdown]
# A continuación se ha definido código Python para ejecutar todas las funciones definidas anteriormente sobre nuestro conjunto de datos.
# En una primera instancia se ejecutó en un único ordenar sin aplicar ninguna técnica de paralelización, al ver que tardaba más de 3 días se decidió aplicar técnicas de paralelización mediante la librería concurrent.features. Aún así, se vió que tardaba también más de 3 días y se dividión el dataset en dos conjuntos de datos que fueron procesados de forma paralela en dos ordenadores distintos y dividiento cada mitad en 8 partes, de esta forma se procesaron los las 16 particiones de forma paralela, 8 en cada ordenador.
# Esto llevó un tiempo de 4 días y medio debido a la gran cantidad de datos que teníamos. El motivo por el que tardaba tanto e spor el cálculo de la calle que tenía que hacer una solicitud registro a registro para obtener la dirección completa y luego extraer la calle. Además que para asegurarnos de que funcionara, mostrábamos por pantalla el valor de la calle.

# %%
def process_dataframe(df_part, filename):
    df_part['neighborhood'] = assign_neighborhood(df_part, 'neighborhoods.geojson')
    df_part['Police_district'] = df_part.apply(lambda row: is_in_district(row['latitude'], row['longitude']), axis=1)
    df_part['Holiday'] = pd.to_datetime(df_part['incident_datetime']).dt.date.apply(is_holiday)
    df_part['Street'] = df_part.apply(lambda row: get_street(row['longitude'], row['latitude']), axis=1)


    df_part.to_csv(filename, index=False)

    return df_part



n_parts = 8
parts = np.array_split(Incidents_c, n_parts)


with concurrent.futures.ThreadPoolExecutor(max_workers=8) as executor:
    futures = []
    for i, part in enumerate(parts):
        filename = f'Incidents_part_{i}.csv'
        futures.append(executor.submit(process_dataframe, part, filename))


    dfs = []
    for future in concurrent.futures.as_completed(futures):
        df_part = future.result()
        dfs.append(df_part)


Incidents_sf = pd.concat(dfs, ignore_index=True)
# Out:
# c:\Python\lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\Python\lib\concurrent\futures\thread.py:58: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   result = self.fn(*self.args, **self.kwargs)
# C:\Users\fatima.elaouni\AppData\Local\Temp\ipykernel_45548\2324694285.py:23: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: +init=epsg:4326 +type=crs
# Right CRS: EPSG:4326
#
#   result = gpd.sjoin(incidents_geo, neighborhoods, how="left", op='intersects')
# c:\Python\lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\Python\lib\concurrent\futures\thread.py:58: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   result = self.fn(*self.args, **self.kwargs)
# C:\Users\fatima.elaouni\AppData\Local\Temp\ipykernel_45548\2324694285.py:23: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: +init=epsg:4326 +type=crs
# Right CRS: EPSG:4326
#
#   result = gpd.sjoin(incidents_geo, neighborhoods, how="left", op='intersects')
# c:\Python\lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\Python\lib\concurrent\futures\thread.py:58: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   result = self.fn(*self.args, **self.kwargs)
# C:\Users\fatima.elaouni\AppData\Local\Temp\ipykernel_45548\2324694285.py:23: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: +init=epsg:4326 +type=crs
# Right CRS: EPSG:4326
#
#   result = gpd.sjoin(incidents_geo, neighborhoods, how="left", op='intersects')
# c:\Python\lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\Python\lib\concurrent\futures\thread.py:58: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   result = self.fn(*self.args, **self.kwargs)
# C:\Users\fatima.elaouni\AppData\Local\Temp\ipykernel_45548\2324694285.py:23: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: +init=epsg:4326 +type=crs
# Right CRS: EPSG:4326
#
#   result = gpd.sjoin(incidents_geo, neighborhoods, how="left", op='intersects')
# c:\Python\lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\Python\lib\concurrent\futures\thread.py:58: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   result = self.fn(*self.args, **self.kwargs)
# C:\Users\fatima.elaouni\AppData\Local\Temp\ipykernel_45548\2324694285.py:23: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: +init=epsg:4326 +type=crs
# Right CRS: EPSG:4326
#
#   result = gpd.sjoin(incidents_geo, neighborhoods, how="left", op='intersects')
# c:\Python\lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\Python\lib\concurrent\futures\thread.py:58: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   result = self.fn(*self.args, **self.kwargs)
# C:\Users\fatima.elaouni\AppData\Local\Temp\ipykernel_45548\2324694285.py:23: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: +init=epsg:4326 +type=crs
# Right CRS: EPSG:4326
#
#   result = gpd.sjoin(incidents_geo, neighborhoods, how="left", op='intersects')
# c:\Python\lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\Python\lib\concurrent\futures\thread.py:58: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   result = self.fn(*self.args, **self.kwargs)
# C:\Users\fatima.elaouni\AppData\Local\Temp\ipykernel_45548\2324694285.py:23: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: +init=epsg:4326 +type=crs
# Right CRS: EPSG:4326
#
#   result = gpd.sjoin(incidents_geo, neighborhoods, how="left", op='intersects')
# Obtenido: 43rd Avenue
# c:\Python\lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\Python\lib\concurrent\futures\thread.py:58: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   result = self.fn(*self.args, **self.kwargs)
# C:\Users\fatima.elaouni\AppData\Local\Temp\ipykernel_45548\2324694285.py:23: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: +init=epsg:4326 +type=crs
# Right CRS: EPSG:4326
#
#   result = gpd.sjoin(incidents_geo, neighborhoods, how="left", op='intersects')
# Obtenido: Fremont Street
# Obtenido: Cesar Chavez Street
# Obtenido: Buchanan Street
# Obtenido: Cabrillo Street
# Obtenido: Charles J. Brenham Place
# Obtenido: Armstrong Avenue
# Obtenido: San Jose Avenue
# Obtenido: Benton Avenue
# Obtenido: None
# Obtenido: Tapia Drive
# Obtenido: Noriega Street
# Obtenido: Bartlett Street
# Obtenido: Octavia Street
# Obtenido: 24th Street
# Obtenido: Hayes Street
# Obtenido: Delancey Street
# Obtenido: None
# Obtenido: Haight Street
# Obtenido: Powell Street
# Obtenido: North Point Street
# Obtenido: Rickard Street
# Obtenido: Lombard Street
# Obtenido: Geary Street
# Obtenido: Orizaba Avenue
# Obtenido: 17th Street
# Obtenido: Sutter Street
# Obtenido: Fillmore Street
# Obtenido: Quesada Avenue
# Obtenido: 23rd Street
# Obtenido: 21st Street
# Obtenido: Zoe Street
# Obtenido: 19th Street
# Obtenido: Eddy Street
# Obtenido: Powell Street
# Obtenido: 24th Street
# Obtenido: Hayes Street
# Obtenido: Silver Avenue
# Obtenido: Cyril Magnin Street
# Obtenido: Kirkham Street
# Obtenido: Ortega Street
# Obtenido: 4th Street
# Obtenido: Loomis Street
# Obtenido: Lombard Street
# Obtenido: Washington Street
# Obtenido: Gold Mine Drive
# Obtenido: Anza Street
# Obtenido: Fillmore Street
# Obtenido: Waller Street
# Obtenido: Olive Street
# Obtenido: 21st Avenue
# Obtenido: None
# Obtenido: Geary Boulevard
# Obtenido: 16th Street
# Obtenido: Fell Street
# Obtenido: 9th Street
# Obtenido: Persia Avenue
# Obtenido: None
# Obtenido: None
# Obtenido: Montgomery Street
# Obtenido: 26th Street
# Obtenido: Leavenworth Street
# Obtenido: California Street
# Obtenido: None
# Obtenido: Hyde Street
# Obtenido: Fern Street
# Obtenido: Arkansas Street
# Obtenido: Franklin Street
# Obtenido: Bay View Street
# Obtenido: Fulton Street
# Obtenido: 19th Street
# Obtenido: Pacific Avenue
# Obtenido: 23rd Street
# Obtenido: Palou Avenue
# Obtenido: Appleton Avenue
# Obtenido: Ellis Street
# Obtenido: Pine Street
# Obtenido: Eddy Street
# Obtenido: Hearst Avenue
# Obtenido: Grove Street
# Obtenido: Turk Street
# Obtenido: Bush Street
# Obtenido: Chestnut Street
# Obtenido: Jones Street
# Obtenido: 18th Street
# Obtenido: 20th Street
# Obtenido: 14th Street
# Obtenido: 24th Street
# Obtenido: 19th Street
# Obtenido: Hudson Avenue
# Obtenido: Beach Street
# Obtenido: Taylor Street
# Obtenido: Amazon Avenue
# Obtenido: Hickory Street
# Obtenido: 4th Street
# Obtenido: Market Street
# Obtenido: O'Farrell Street
# Obtenido: Columbus Avenue
# Obtenido: Geary Street
# Obtenido: Anza Street
# Obtenido: Alameda Street
# Obtenido: Gold Mine Drive
# Obtenido: Tandang Sora Street
# Obtenido: Waller Street
# Obtenido: 23rd Street
# Obtenido: Bush Street
# Obtenido: Pine Street
# Obtenido: None
# Obtenido: 4th Street
# Obtenido: Washington Street
# Obtenido: Lexington Street
# Obtenido: 9th Street
# Obtenido: Buchanan Street
# Obtenido: Van Ness Avenue
# Obtenido: 22nd Street
# Obtenido: 4th Street
# Obtenido: Oak Street
# Obtenido: Eugenia Avenue
# Obtenido: San Jose Avenue
# Obtenido: Russia Avenue
# Obtenido: Judah Street
# Obtenido: None
# Obtenido: Fell Street
# Obtenido: Jamestown Avenue
# Obtenido: None
# Obtenido: Pine Street
# Obtenido: 23rd Street
# Obtenido: Sutter Street
# Obtenido: Post Street
# Obtenido: None
# Obtenido: Beach Street
# Obtenido: None
# Obtenido: None
# Obtenido: Kirkham Street
# Obtenido: 12th Avenue
# Obtenido: Leland Avenue
# Obtenido: Turk Street
# Obtenido: Page Street
# Obtenido: Clay Street
# Obtenido: Filbert Street
# Obtenido: Cabrillo Street
# Obtenido: North Point Street
# Obtenido: Santos Street
# Obtenido: Jennings Street
# Obtenido: None
# Obtenido: Golden Gate Avenue
# Obtenido: Taylor Street
# Obtenido: Holloway Avenue
# Obtenido: Balboa Street
# Obtenido: Chenery Street
# Obtenido: Hyde Street
# Obtenido: 18th Street
# -----------------------RESULTADO--------------------------
#           incident_datetime incident_day_of_week  incident_code  \
# 253851  2019-10-12 13:30:00             Saturday           6244
# 119339  2018-10-25 20:00:00             Thursday          71013
# 328134  2020-05-16 19:35:00             Saturday          27065
# 639223  2022-12-13 19:58:00              Tuesday           5013
# 598927  2022-08-24 17:30:00            Wednesday           6244
# 358169  2020-08-24 17:04:00               Monday          71000
# 82440   2018-07-27 13:00:00               Friday           4138
# 145885  2019-01-03 13:22:00             Thursday          62050
# 171701  2019-03-15 00:00:00               Friday          75030
# 560923  2022-05-06 11:33:00               Friday           3471
# 303253  2020-02-19 17:35:00            Wednesday          68020
# 258501  2019-10-24 18:55:00             Thursday           6374
# 223809  2019-07-31 10:15:00            Wednesday           6244
# 274628  2019-12-04 20:25:00            Wednesday           6244
# 86705   2018-08-06 07:45:00               Monday           6244
# 340517  2020-06-27 13:30:00             Saturday          64080
# 611502  2022-09-26 01:57:00               Monday           4013
# 327232  2020-05-13 12:56:00            Wednesday          64020
# 565717  2022-05-22 21:00:00               Sunday           4134
# 56380   2018-05-23 08:30:00            Wednesday          11012
#
#                   incident_category         incident_subcategory  \
# 253851                LARCENY THEFT       LARCENY - FROM VEHICLE
# 119339                LARCENY THEFT           THEFT FROM VEHICLE
# 328134          OTHER MISCELLANEOUS                        FRAUD
# 639223                     BURGLARY       BURGLARY - RESIDENTIAL
# 598927                LARCENY THEFT       LARCENY - FROM VEHICLE
# 358169                LOST PROPERTY                LOST PROPERTY
# 82440                       ASSAULT               SIMPLE ASSAULT
# 145885                      WARRANT                      WARRANT
# 171701                 CASE CLOSURE                 CASE CLOSURE
# 560923                      ROBBERY              ROBBERY - OTHER
# 303253  MISCELLANEOUS INVESTIGATION  MISCELLANEOUS INVESTIGATION
# 258501                LARCENY THEFT        LARCENY THEFT - OTHER
# 223809                LARCENY THEFT       LARCENY - FROM VEHICLE
# 274628                LARCENY THEFT       LARCENY - FROM VEHICLE
# 86705                 LARCENY THEFT       LARCENY - FROM VEHICLE
# 340517               SUSPICIOUS OCC               SUSPICIOUS OCC
# 611502                      ASSAULT           AGGRAVATED ASSAULT
# 327232                 NON-CRIMINAL                        OTHER
# 565717                      ASSAULT               SIMPLE ASSAULT
# 56380               STOLEN PROPERTY              STOLEN PROPERTY
#
#                   resolution   latitude   longitude  \
# 253851        Open or Active  37.735206 -122.501097
# 119339        Open or Active  37.720724 -122.446609
# 328134  Cite or Arrest Adult  37.775626 -122.432830
# 639223        Open or Active  37.786940 -122.411516
# 598927        Open or Active  37.779721 -122.395835
# 358169        Open or Active  37.760405 -122.463912
# 82440   Cite or Arrest Adult  37.802628 -122.436693
# 145885  Cite or Arrest Adult  37.775801 -122.414173
# 171701             Unfounded  37.775161 -122.403636
# 560923        Open or Active  37.792088 -122.444656
# 303253             Unfounded  37.775925 -122.437990
# 258501        Open or Active  37.752171 -122.419557
# 223809        Open or Active  37.768770 -122.427462
# 274628        Open or Active  37.769284 -122.445106
# 86705         Open or Active  37.775801 -122.414173
# 340517        Open or Active  37.716997 -122.427572
# 611502        Open or Active  37.787757 -122.420116
# 327232        Open or Active  37.712283 -122.406529
# 565717        Open or Active  37.729543 -122.386418
# 56380   Cite or Arrest Adult  37.762229 -122.412844
#
#                            geometry           neighborhood Police_district  \
# 253851  POINT (-122.50110 37.73521)              Lakeshore         TARAVAL
# 119339  POINT (-122.44661 37.72072)          Outer Mission       INGLESIDE
# 328134  POINT (-122.43283 37.77563)           Hayes Valley        NORTHERN
# 639223  POINT (-122.41152 37.78694)             Tenderloin         CENTRAL
# 598927  POINT (-122.39584 37.77972)        South of Market        SOUTHERN
# 358169  POINT (-122.46391 37.76041)           Inner Sunset            PARK
# 82440   POINT (-122.43669 37.80263)                 Marina        NORTHERN
# 145885  POINT (-122.41417 37.77580)        South of Market        SOUTHERN
# 171701  POINT (-122.40364 37.77516)        South of Market        SOUTHERN
# 560923  POINT (-122.44466 37.79209)        Pacific Heights        RICHMOND
# 303253  POINT (-122.43799 37.77593)           Hayes Valley        NORTHERN
# 258501  POINT (-122.41956 37.75217)                Mission         MISSION
# 223809  POINT (-122.42746 37.76877)    Castro/Upper Market         MISSION
# 274628  POINT (-122.44511 37.76928)         Haight Ashbury            PARK
# 86705   POINT (-122.41417 37.77580)        South of Market        SOUTHERN
# 340517  POINT (-122.42757 37.71700)              Excelsior       INGLESIDE
# 611502  POINT (-122.42012 37.78776)               Nob Hill        NORTHERN
# 327232  POINT (-122.40653 37.71228)      Visitacion Valley       INGLESIDE
# 565717  POINT (-122.38642 37.72954)  Bayview Hunters Point         BAYVIEW
# 56380   POINT (-122.41284 37.76223)                Mission         MISSION
#
#        Holiday           Street
# 253851    None      43rd Avenue
# 119339    None  San Jose Avenue
# 328134    None     Hayes Street
# 639223    None     Geary Street
# 598927    None       Zoe Street
# 358169    None   Kirkham Street
# 82440     None  Fillmore Street
# 145885    None       9th Street
# 171701    None             None
# 560923    None   Pacific Avenue
# 303253    None     Grove Street
# 258501    None      24th Street
# 223809    None    Market Street
# 274628    None    Waller Street
# 86705     None       9th Street
# 340517    None    Russia Avenue
# 611502    None    Sutter Street
# 327232    None    Leland Avenue
# 565717    None  Jennings Street
# 56380     None      18th Street
# -----------------------TIPO--------------------------
# <class 'pandas.core.frame.DataFrame'>
# Obtenido: North Point Street
# Obtenido: 21st Street
# -----------------------RESULTADO--------------------------
#           incident_datetime incident_day_of_week  incident_code  \
# 65386   2018-06-16 02:10:00             Saturday           6374
# 425009  2021-03-31 21:33:00            Wednesday          64085
# 513347  2021-12-13 12:26:00               Monday           6362
# 421789  2021-03-20 08:09:00             Saturday          65016
# 120000  2018-10-27 12:40:00             Saturday           9250
# 444532  2021-06-01 00:00:00              Tuesday          27145
# 352493  2020-08-05 10:54:00            Wednesday          65010
# 117939  2018-10-22 11:30:00               Monday           6244
# 243492  2019-09-17 09:20:00              Tuesday           6243
# 518692  2021-12-30 11:14:00             Thursday           7046
# 307202  2020-03-01 00:00:00               Sunday           9024
# 412356  2021-02-17 21:00:00            Wednesday           6302
# 21752   2018-02-24 13:00:00             Saturday           6244
# 274002  2019-12-03 04:10:00              Tuesday          61030
# 360609  2020-09-02 11:30:00            Wednesday           6314
# 171659  2019-03-15 12:00:00               Friday          75000
# 261648  2019-10-31 21:55:00             Thursday          65010
# 523753  2022-01-15 16:00:00             Saturday           7021
# 412593  2021-02-17 22:32:00            Wednesday          16654
# 61764   2018-06-06 12:00:00            Wednesday          74000
#
#                incident_category           incident_subcategory  \
# 65386              LARCENY THEFT          LARCENY THEFT - OTHER
# 425009       OTHER MISCELLANEOUS                          OTHER
# 513347             LARCENY THEFT    LARCENY THEFT - SHOPLIFTING
# 421789       OTHER MISCELLANEOUS                          OTHER
# 120000                     FRAUD                          FRAUD
# 444532       OTHER MISCELLANEOUS                          OTHER
# 352493  TRAFFIC VIOLATION ARREST       TRAFFIC VIOLATION ARREST
# 117939             LARCENY THEFT         LARCENY - FROM VEHICLE
# 243492             LARCENY THEFT         LARCENY - FROM VEHICLE
# 518692         RECOVERED VEHICLE              RECOVERED VEHICLE
# 307202                     FRAUD                          FRAUD
# 412356             LARCENY THEFT  LARCENY THEFT - FROM BUILDING
# 21752              LARCENY THEFT         LARCENY - FROM VEHICLE
# 274002                     OTHER                          OTHER
# 360609             LARCENY THEFT        LARCENY THEFT - BICYCLE
# 171659            MISSING PERSON                 MISSING PERSON
# 261648  TRAFFIC VIOLATION ARREST       TRAFFIC VIOLATION ARREST
# 523753       MOTOR VEHICLE THEFT            MOTOR VEHICLE THEFT
# 412593              DRUG OFFENSE                 DRUG VIOLATION
# 61764             MISSING PERSON                  MISSING ADULT
#
#                   resolution   latitude   longitude  \
# 65386         Open or Active  37.789235 -122.395151
# 425009        Open or Active  37.780162 -122.407691
# 513347        Open or Active  37.784044 -122.403712
# 421789  Cite or Arrest Adult  37.763429 -122.419513
# 120000        Open or Active  37.780588 -122.438927
# 444532        Open or Active  37.773467 -122.391434
# 352493  Cite or Arrest Adult  37.784501 -122.419455
# 117939        Open or Active  37.782119 -122.407255
# 243492        Open or Active  37.787805 -122.423498
# 518692        Open or Active  37.727785 -122.379992
# 307202        Open or Active  37.791128 -122.401130
# 412356        Open or Active  37.732422 -122.380185
# 21752         Open or Active  37.806241 -122.418782
# 274002        Open or Active  37.790805 -122.403672
# 360609        Open or Active  37.775422 -122.419397
# 171659        Open or Active  37.779658 -122.409283
# 261648  Cite or Arrest Adult  37.778861 -122.408272
# 523753        Open or Active  37.773039 -122.430629
# 412593  Cite or Arrest Adult  37.781654 -122.415505
# 61764         Open or Active  37.757762 -122.406800
#
#                            geometry                    neighborhood  \
# 65386   POINT (-122.39515 37.78923)  Financial District/South Beach
# 425009  POINT (-122.40769 37.78016)                 South of Market
# 513347  POINT (-122.40371 37.78404)  Financial District/South Beach
# 421789  POINT (-122.41951 37.76343)                         Mission
# 120000  POINT (-122.43893 37.78059)                Western Addition
# 444532  POINT (-122.39143 37.77347)                     Mission Bay
# 352493  POINT (-122.41945 37.78450)                      Tenderloin
# 117939  POINT (-122.40725 37.78212)                 South of Market
# 243492  POINT (-122.42350 37.78781)                Western Addition
# 518692  POINT (-122.37999 37.72779)           Bayview Hunters Point
# 307202  POINT (-122.40113 37.79113)  Financial District/South Beach
# 412356  POINT (-122.38018 37.73242)           Bayview Hunters Point
# 21752   POINT (-122.41878 37.80624)                     North Beach
# 274002  POINT (-122.40367 37.79081)  Financial District/South Beach
# 360609  POINT (-122.41940 37.77542)                    Hayes Valley
# 171659  POINT (-122.40928 37.77966)                 South of Market
# 261648  POINT (-122.40827 37.77886)                 South of Market
# 523753  POINT (-122.43063 37.77304)                    Hayes Valley
# 412593  POINT (-122.41551 37.78165)                      Tenderloin
# 61764   POINT (-122.40680 37.75776)                         Mission
#
#        Police_district Holiday              Street
# 65386         SOUTHERN    None      Fremont Street
# 425009        SOUTHERN    Both                None
# 513347        SOUTHERN    None                None
# 421789         MISSION    None         17th Street
# 120000        NORTHERN    None         Eddy Street
# 444532        SOUTHERN    None          4th Street
# 352493        NORTHERN    None        Olive Street
# 117939        SOUTHERN    None                None
# 243492        NORTHERN    None         Fern Street
# 518692         BAYVIEW    None        Palou Avenue
# 307202         CENTRAL    None         Bush Street
# 412356         BAYVIEW    None       Hudson Avenue
# 21752          CENTRAL    None     Columbus Avenue
# 274002         CENTRAL    None         Bush Street
# 360609        NORTHERN    None     Van Ness Avenue
# 171659        SOUTHERN    None                None
# 261648        SOUTHERN    None                None
# 523753        NORTHERN    None         Page Street
# 412593      TENDERLOIN    None  Golden Gate Avenue
# 61764          MISSION    None         21st Street
# -----------------------TIPO--------------------------
# <class 'pandas.core.frame.DataFrame'>
# Obtenido: Fillmore Street
# -----------------------RESULTADO--------------------------
#           incident_datetime incident_day_of_week  incident_code  \
# 12190   2018-01-31 09:55:00            Wednesday          75000
# 492794  2021-10-18 16:11:00               Monday           7045
# 437736  2021-05-12 14:30:00            Wednesday          28150
# 365131  2020-09-17 16:55:00             Thursday          64085
# 584096  2022-07-13 06:40:00            Wednesday          27065
# 633706  2022-11-27 03:46:00               Sunday          72000
# 436690  2021-05-09 22:29:00               Sunday          27175
# 115439  2018-10-16 14:11:00              Tuesday          62050
# 88927   2018-08-11 17:00:00             Saturday          28150
# 80716   2018-07-24 13:17:00              Tuesday           9031
# 70837   2018-06-30 22:34:00             Saturday          63010
# 417024  2021-03-03 03:59:00            Wednesday          26170
# 278078  2019-12-13 11:42:00               Friday           3401
# 664204  2023-02-26 18:16:00               Sunday          71000
# 403161  2021-01-19 22:00:00              Tuesday           7051
# 230917  2019-08-18 15:00:00               Sunday           6244
# 62033   2018-06-07 10:30:00             Thursday           6243
# 60856   2018-06-04 21:00:00               Monday           6374
# 528716  2022-01-30 18:30:00               Sunday          28150
# 572382  2022-06-11 15:00:00             Saturday           6244
#
#           incident_category             incident_subcategory  \
# 12190        MISSING PERSON                   MISSING PERSON
# 492794    RECOVERED VEHICLE                RECOVERED VEHICLE
# 437736   MALICIOUS MISCHIEF                        VANDALISM
# 365131  OTHER MISCELLANEOUS                            OTHER
# 584096  OTHER MISCELLANEOUS                            FRAUD
# 633706         NON-CRIMINAL                     NON-CRIMINAL
# 436690  OTHER MISCELLANEOUS                            OTHER
# 115439              WARRANT                          WARRANT
# 88927    MALICIOUS MISCHIEF                        VANDALISM
# 80716       STOLEN PROPERTY                  STOLEN PROPERTY
# 70837               WARRANT                            OTHER
# 417024  OTHER MISCELLANEOUS                            OTHER
# 278078              ROBBERY             ROBBERY - COMMERCIAL
# 664204        LOST PROPERTY                    LOST PROPERTY
# 403161  MOTOR VEHICLE THEFT  MOTOR VEHICLE THEFT (ATTEMPTED)
# 230917        LARCENY THEFT           LARCENY - FROM VEHICLE
# 62033         LARCENY THEFT           LARCENY - FROM VEHICLE
# 60856         LARCENY THEFT            LARCENY THEFT - OTHER
# 528716   MALICIOUS MISCHIEF                        VANDALISM
# 572382        LARCENY THEFT           LARCENY - FROM VEHICLE
#
#                   resolution   latitude   longitude  \
# 12190         Open or Active  37.749804 -122.395308
# 492794        Open or Active  37.720399 -122.481354
# 437736        Open or Active  37.769526 -122.450710
# 365131        Open or Active  37.789434 -122.406957
# 584096  Cite or Arrest Adult  37.786410 -122.408036
# 633706        Open or Active  37.738321 -122.405647
# 436690        Open or Active  37.780280 -122.480451
# 115439  Cite or Arrest Adult  37.775161 -122.403636
# 88927         Open or Active  37.763736 -122.398580
# 80716         Open or Active  37.738601 -122.423353
# 70837   Cite or Arrest Adult  37.799765 -122.444516
# 417024  Cite or Arrest Adult  37.807483 -122.413975
# 278078        Open or Active  37.786940 -122.411516
# 664204        Open or Active  37.790673 -122.412266
# 403161        Open or Active  37.755568 -122.416567
# 230917        Open or Active  37.772995 -122.445902
# 62033         Open or Active  37.803284 -122.446910
# 60856         Open or Active  37.793432 -122.412829
# 528716        Open or Active  37.808214 -122.415802
# 572382        Open or Active  37.799843 -122.436046
#
#                            geometry                    neighborhood  \
# 12190   POINT (-122.39531 37.74980)           Bayview Hunters Point
# 492794  POINT (-122.48135 37.72040)                       Lakeshore
# 437736  POINT (-122.45071 37.76953)                  Haight Ashbury
# 365131  POINT (-122.40696 37.78943)  Financial District/South Beach
# 584096  POINT (-122.40804 37.78641)                      Tenderloin
# 633706  POINT (-122.40565 37.73832)           Bayview Hunters Point
# 436690  POINT (-122.48045 37.78028)                  Outer Richmond
# 115439  POINT (-122.40364 37.77516)                 South of Market
# 88927   POINT (-122.39858 37.76374)                    Potrero Hill
# 80716   POINT (-122.42335 37.73860)                  Bernal Heights
# 70837   POINT (-122.44452 37.79977)                          Marina
# 417024  POINT (-122.41398 37.80748)                     North Beach
# 278078  POINT (-122.41152 37.78694)                      Tenderloin
# 664204  POINT (-122.41227 37.79067)                        Nob Hill
# 403161  POINT (-122.41657 37.75557)                         Mission
# 230917  POINT (-122.44590 37.77300)               Lone Mountain/USF
# 62033   POINT (-122.44691 37.80328)                          Marina
# 60856   POINT (-122.41283 37.79343)                        Nob Hill
# 528716  POINT (-122.41580 37.80821)                     North Beach
# 572382  POINT (-122.43605 37.79984)                          Marina
#
#        Police_district Holiday               Street
# 12190          BAYVIEW    None  Cesar Chavez Street
# 492794         TARAVAL    None          Tapia Drive
# 437736            PARK    None        Haight Street
# 365131         CENTRAL    None        Sutter Street
# 584096         CENTRAL    None        Powell Street
# 633706         BAYVIEW    None        Loomis Street
# 436690        RICHMOND    None          21st Avenue
# 115439        SOUTHERN    None                 None
# 88927          BAYVIEW    None      Arkansas Street
# 80716        INGLESIDE    None      Appleton Avenue
# 70837         NORTHERN    None      Chestnut Street
# 417024         CENTRAL    None         Beach Street
# 278078         CENTRAL    None         Geary Street
# 664204         CENTRAL    None          Pine Street
# 403161         MISSION    None          22nd Street
# 230917            PARK    None          Fell Street
# 62033         NORTHERN    None         Beach Street
# 60856          CENTRAL    None          Clay Street
# 528716         CENTRAL    None        Taylor Street
# 572382        NORTHERN    None      Fillmore Street
# -----------------------TIPO--------------------------
# <class 'pandas.core.frame.DataFrame'>
# Obtenido: Turk Street
# -----------------------RESULTADO--------------------------
#           incident_datetime incident_day_of_week  incident_code  \
# 517683  2021-12-27 17:00:00               Monday           6244
# 280479  2019-12-20 22:00:00               Friday           6244
# 485024  2021-09-27 05:00:00               Monday           5051
# 594990  2022-08-13 08:05:00             Saturday          64080
# 90656   2018-08-16 09:43:00             Thursday          26040
# 589818  2022-07-29 15:00:00               Friday           6243
# 350653  2020-07-30 09:09:00             Thursday           4134
# 101794  2018-09-12 18:55:00            Wednesday          26080
# 292106  2020-01-20 06:10:00               Monday           5071
# 615191  2022-10-06 13:00:00             Thursday          12030
# 521684  2022-01-08 11:59:00             Saturday          68000
# 495665  2021-10-26 00:00:00              Tuesday           6123
# 291283  2020-01-18 15:00:00             Saturday          72000
# 123462  2018-11-05 11:07:00               Monday          16130
# 355211  2020-08-14 11:11:00               Friday          15200
# 515343  2021-12-19 01:00:00               Sunday           6374
# 554485  2022-04-17 00:00:00               Sunday          28160
# 353573  2020-08-09 21:37:00               Sunday           5042
# 221921  2019-07-27 07:30:00             Saturday          72000
# 266384  2019-11-12 03:00:00              Tuesday           7020
#
#                                incident_category    incident_subcategory  \
# 517683                             LARCENY THEFT  LARCENY - FROM VEHICLE
# 280479                             LARCENY THEFT  LARCENY - FROM VEHICLE
# 485024                                  BURGLARY   BURGLARY - COMMERCIAL
# 594990                            SUSPICIOUS OCC          SUSPICIOUS OCC
# 90656                        OTHER MISCELLANEOUS     EXTORTION-BLACKMAIL
# 589818                             LARCENY THEFT  LARCENY - FROM VEHICLE
# 350653                                   ASSAULT          SIMPLE ASSAULT
# 101794                       OTHER MISCELLANEOUS                   OTHER
# 292106                                  BURGLARY        BURGLARY - OTHER
# 615191                           WEAPONS OFFENSE         WEAPONS OFFENSE
# 521684                               FIRE REPORT             FIRE REPORT
# 495665                             LARCENY THEFT   LARCENY THEFT - OTHER
# 291283                              NON-CRIMINAL            NON-CRIMINAL
# 123462                              DRUG OFFENSE          DRUG VIOLATION
# 355211  OFFENCES AGAINST THE FAMILY AND CHILDREN                   OTHER
# 515343                             LARCENY THEFT   LARCENY THEFT - OTHER
# 554485                        MALICIOUS MISCHIEF               VANDALISM
# 353573                                  BURGLARY  BURGLARY - RESIDENTIAL
# 221921                              NON-CRIMINAL            NON-CRIMINAL
# 266384                       MOTOR VEHICLE THEFT     MOTOR VEHICLE THEFT
#
#                   resolution   latitude   longitude  \
# 517683        Open or Active  37.785564 -122.429783
# 280479        Open or Active  37.754146 -122.478616
# 485024        Open or Active  37.786410 -122.408036
# 594990        Open or Active  37.806262 -122.437433
# 90656         Open or Active  37.752204 -122.419018
# 589818        Open or Active  37.802201 -122.417966
# 350653        Open or Active  37.781754 -122.409693
# 101794  Cite or Arrest Adult  37.805696 -122.405357
# 292106        Open or Active  37.786868 -122.423308
# 615191  Cite or Arrest Adult  37.784866 -122.412782
# 521684        Open or Active  37.794110 -122.414648
# 495665        Open or Active  37.808214 -122.415802
# 291283        Open or Active  37.779091 -122.464145
# 123462  Cite or Arrest Adult  37.779459 -122.402377
# 355211        Open or Active  37.773467 -122.391434
# 515343        Open or Active  37.719558 -122.395431
# 554485        Open or Active  37.778943 -122.406163
# 353573        Open or Active  37.798648 -122.430747
# 221921        Open or Active  37.721624 -122.472322
# 266384        Open or Active  37.784236 -122.417707
#
#                            geometry           neighborhood Police_district  \
# 517683  POINT (-122.42978 37.78556)              Japantown        NORTHERN
# 280479  POINT (-122.47862 37.75415)        Sunset/Parkside         TARAVAL
# 485024  POINT (-122.40804 37.78641)             Tenderloin         CENTRAL
# 594990  POINT (-122.43743 37.80626)                 Marina        NORTHERN
# 90656   POINT (-122.41902 37.75220)                Mission         MISSION
# 589818  POINT (-122.41797 37.80220)           Russian Hill         CENTRAL
# 350653  POINT (-122.40969 37.78175)        South of Market      TENDERLOIN
# 101794  POINT (-122.40536 37.80570)            North Beach         CENTRAL
# 292106  POINT (-122.42331 37.78687)       Western Addition        NORTHERN
# 615191  POINT (-122.41278 37.78487)             Tenderloin      TENDERLOIN
# 521684  POINT (-122.41465 37.79411)               Nob Hill         CENTRAL
# 495665  POINT (-122.41580 37.80821)            North Beach         CENTRAL
# 291283  POINT (-122.46414 37.77909)         Inner Richmond        RICHMOND
# 123462  POINT (-122.40238 37.77946)        South of Market        SOUTHERN
# 355211  POINT (-122.39143 37.77347)            Mission Bay        SOUTHERN
# 515343  POINT (-122.39543 37.71956)  Bayview Hunters Point         BAYVIEW
# 554485  POINT (-122.40616 37.77894)        South of Market        SOUTHERN
# 353573  POINT (-122.43075 37.79865)                 Marina        NORTHERN
# 221921  POINT (-122.47232 37.72162)     West of Twin Peaks         TARAVAL
# 266384  POINT (-122.41771 37.78424)             Tenderloin      TENDERLOIN
#
#        Holiday             Street
# 517683    None    Buchanan Street
# 280479    None     Noriega Street
# 485024    None      Powell Street
# 594990    None    Fillmore Street
# 90656     None        24th Street
# 589818    None     Lombard Street
# 350653    None               None
# 101794    None  Montgomery Street
# 292106    Both    Franklin Street
# 615191    None       Ellis Street
# 521684    None       Jones Street
# 495665    None      Taylor Street
# 291283    None        Anza Street
# 123462    None               None
# 355211    None         4th Street
# 515343    None   Jamestown Avenue
# 554485    None               None
# 353573    None     Filbert Street
# 221921    None    Holloway Avenue
# 266384    None        Turk Street
# -----------------------TIPO--------------------------
# <class 'pandas.core.frame.DataFrame'>
# Obtenido: Stevenson Street
# -----------------------RESULTADO--------------------------
#           incident_datetime incident_day_of_week  incident_code  \
# 59682   2018-06-01 21:30:00               Friday           6223
# 488347  2021-10-06 18:00:00            Wednesday           7023
# 611333  2022-09-26 21:30:00               Monday           6243
# 184115  2019-04-18 12:38:00             Thursday          65030
# 256659  2019-10-19 04:00:00             Saturday           6244
# 457213  2021-07-08 22:34:00             Thursday           6241
# 6302    2018-01-16 07:53:00              Tuesday           6244
# 259150  2019-10-25 22:00:00               Friday           4134
# 319953  2020-04-16 16:38:00             Thursday          65016
# 31672   2018-03-22 21:00:00             Thursday           6244
# 452791  2021-06-26 21:30:00             Saturday          51040
# 227759  2019-08-10 18:25:00             Saturday          28150
# 671604  2023-03-20 15:30:00               Monday           7025
# 100632  2018-09-09 18:22:00               Sunday          12120
# 10088   2018-01-26 08:00:00               Friday          28150
# 118139  2018-10-22 00:30:00               Monday           4134
# 478671  2021-09-10 14:00:00               Friday           4134
# 82395   2018-07-27 14:26:00               Friday           7041
# 210832  2019-06-29 03:00:00             Saturday          28150
# 191072  2019-05-07 20:30:00              Tuesday           6374
#
#            incident_category    incident_subcategory            resolution  \
# 59682          LARCENY THEFT  LARCENY - FROM VEHICLE        Open or Active
# 488347   MOTOR VEHICLE THEFT     MOTOR VEHICLE THEFT        Open or Active
# 611333         LARCENY THEFT  LARCENY - FROM VEHICLE        Open or Active
# 184115   OTHER MISCELLANEOUS                   OTHER  Cite or Arrest Adult
# 256659         LARCENY THEFT  LARCENY - FROM VEHICLE        Open or Active
# 457213         LARCENY THEFT  LARCENY - FROM VEHICLE        Open or Active
# 6302           LARCENY THEFT  LARCENY - FROM VEHICLE        Open or Active
# 259150               ASSAULT          SIMPLE ASSAULT  Cite or Arrest Adult
# 319953   OTHER MISCELLANEOUS                   OTHER  Cite or Arrest Adult
# 31672          LARCENY THEFT  LARCENY - FROM VEHICLE        Open or Active
# 452791          NON-CRIMINAL            NON-CRIMINAL        Open or Active
# 227759    MALICIOUS MISCHIEF               VANDALISM        Open or Active
# 671604   MOTOR VEHICLE THEFT     MOTOR VEHICLE THEFT        Open or Active
# 100632  WEAPONS CARRYING ETC         WEAPONS OFFENSE  Cite or Arrest Adult
# 10088     MALICIOUS MISCHIEF               VANDALISM        Open or Active
# 118139               ASSAULT          SIMPLE ASSAULT        Open or Active
# 478671               ASSAULT          SIMPLE ASSAULT  Cite or Arrest Adult
# 82395      RECOVERED VEHICLE       RECOVERED VEHICLE        Open or Active
# 210832    MALICIOUS MISCHIEF               VANDALISM     Exceptional Adult
# 191072         LARCENY THEFT   LARCENY THEFT - OTHER        Open or Active
#
#          latitude   longitude                     geometry  \
# 59682   37.775077 -122.470298  POINT (-122.47030 37.77508)
# 488347  37.750573 -122.419400  POINT (-122.41940 37.75057)
# 611333  37.805497 -122.422007  POINT (-122.42201 37.80550)
# 184115  37.730167 -122.385853  POINT (-122.38585 37.73017)
# 256659  37.776688 -122.424514  POINT (-122.42451 37.77669)
# 457213  37.796347 -122.396958  POINT (-122.39696 37.79635)
# 6302    37.782488 -122.445821  POINT (-122.44582 37.78249)
# 259150  37.749041 -122.418135  POINT (-122.41814 37.74904)
# 319953  37.732488 -122.392358  POINT (-122.39236 37.73249)
# 31672   37.793097 -122.396504  POINT (-122.39650 37.79310)
# 452791  37.760889 -122.435001  POINT (-122.43500 37.76089)
# 227759  37.717245 -122.440418  POINT (-122.44042 37.71724)
# 671604  37.768178 -122.410731  POINT (-122.41073 37.76818)
# 100632  37.784908 -122.404795  POINT (-122.40480 37.78491)
# 10088   37.772922 -122.439089  POINT (-122.43909 37.77292)
# 118139  37.781398 -122.409245  POINT (-122.40925 37.78140)
# 478671  37.780162 -122.407691  POINT (-122.40769 37.78016)
# 82395   37.774437 -122.484326  POINT (-122.48433 37.77444)
# 210832  37.777380 -122.460796  POINT (-122.46080 37.77738)
# 191072  37.769339 -122.421470  POINT (-122.42147 37.76934)
#
#                           neighborhood Police_district Holiday  \
# 59682                   Inner Richmond        RICHMOND    None
# 488347                         Mission         MISSION    None
# 611333                    Russian Hill         CENTRAL    None
# 184115           Bayview Hunters Point         BAYVIEW    None
# 256659                    Hayes Valley        NORTHERN    None
# 457213  Financial District/South Beach         CENTRAL    None
# 6302                 Lone Mountain/USF        RICHMOND    None
# 259150                         Mission         MISSION    None
# 319953           Bayview Hunters Point         BAYVIEW    None
# 31672   Financial District/South Beach         CENTRAL    None
# 452791             Castro/Upper Market         MISSION    None
# 227759                       Excelsior       INGLESIDE    None
# 671604                         Mission         MISSION    None
# 100632  Financial District/South Beach      TENDERLOIN    None
# 10088                   Haight Ashbury            PARK    None
# 118139                 South of Market      TENDERLOIN    None
# 478671                 South of Market        SOUTHERN    None
# 82395                   Outer Richmond        RICHMOND    None
# 210832                  Inner Richmond        RICHMOND    None
# 191072                         Mission         MISSION    None
#
#                     Street
# 59682      Cabrillo Street
# 488347     Bartlett Street
# 611333  North Point Street
# 184115      Quesada Avenue
# 256659        Hayes Street
# 457213   Washington Street
# 6302       Geary Boulevard
# 259150         26th Street
# 319953     Bay View Street
# 31672          Pine Street
# 452791         18th Street
# 227759       Amazon Avenue
# 671604      Alameda Street
# 100632          4th Street
# 10088           Oak Street
# 118139                None
# 478671                None
# 82395      Cabrillo Street
# 210832       Balboa Street
# 191072    Stevenson Street
# -----------------------TIPO--------------------------
# <class 'pandas.core.frame.DataFrame'>
# Obtenido: 25th Street
# -----------------------RESULTADO--------------------------
#           incident_datetime incident_day_of_week  incident_code  \
# 326909  2020-05-12 12:00:00              Tuesday           9320
# 669838  2023-03-15 22:51:00            Wednesday           7041
# 230834  2019-08-17 09:38:00             Saturday           4134
# 563308  2022-05-14 01:01:00             Saturday           6244
# 320591  2020-04-18 12:00:00             Saturday          27195
# 619836  2022-10-18 01:56:00              Tuesday           7041
# 384070  2020-11-19 10:40:00             Thursday           4134
# 597950  2022-08-21 15:30:00               Sunday           6224
# 581150  2022-07-05 19:10:00              Tuesday           6244
# 422853  2021-03-24 09:59:00            Wednesday          75000
# 224525  2019-08-02 17:18:00               Friday          26149
# 187535  2019-04-27 22:00:00             Saturday           6244
# 511900  2021-12-09 14:00:00             Thursday           5041
# 473613  2021-08-26 00:57:00             Thursday           4134
# 142430  2018-12-25 00:00:00              Tuesday           6244
# 28348   2018-03-13 19:00:00              Tuesday           5043
# 458129  2021-07-10 22:00:00             Saturday           5081
# 616582  2022-10-09 18:55:00               Sunday           6244
# 432904  2021-04-27 05:26:00              Tuesday          28100
# 412714  2021-02-18 22:30:00             Thursday           7025
#
#           incident_category    incident_subcategory            resolution  \
# 326909                FRAUD                   FRAUD        Open or Active
# 669838    RECOVERED VEHICLE       RECOVERED VEHICLE        Open or Active
# 230834              ASSAULT          SIMPLE ASSAULT  Cite or Arrest Adult
# 563308        LARCENY THEFT  LARCENY - FROM VEHICLE        Open or Active
# 320591  OTHER MISCELLANEOUS                TRESPASS        Open or Active
# 619836    RECOVERED VEHICLE       RECOVERED VEHICLE        Open or Active
# 384070              ASSAULT          SIMPLE ASSAULT        Open or Active
# 597950        LARCENY THEFT  LARCENY - FROM VEHICLE        Open or Active
# 581150        LARCENY THEFT  LARCENY - FROM VEHICLE        Open or Active
# 422853       MISSING PERSON          MISSING PERSON        Open or Active
# 224525  OTHER MISCELLANEOUS              KIDNAPPING        Open or Active
# 187535        LARCENY THEFT  LARCENY - FROM VEHICLE        Open or Active
# 511900             BURGLARY  BURGLARY - RESIDENTIAL        Open or Active
# 473613              ASSAULT          SIMPLE ASSAULT        Open or Active
# 142430        LARCENY THEFT  LARCENY - FROM VEHICLE        Open or Active
# 28348              BURGLARY  BURGLARY - RESIDENTIAL        Open or Active
# 458129             BURGLARY    BURGLARY - HOT PROWL        Open or Active
# 616582        LARCENY THEFT  LARCENY - FROM VEHICLE        Open or Active
# 432904   MALICIOUS MISCHIEF               VANDALISM        Open or Active
# 412714  MOTOR VEHICLE THEFT     MOTOR VEHICLE THEFT        Open or Active
#
#          latitude   longitude                     geometry     neighborhood  \
# ...
# 581150  37.777281 -122.434864  POINT (-122.43486 37.77728)     Hayes Valley
# 422853  37.783933 -122.412595  POINT (-122.41260 37.78393)       Tenderloin
# 224525  37.758365 -122.423489  POINT (-122.42349 37.75836)          Mission
# 187535  37.775311 -122.424075  POINT (-122.42407 37.77531)     Hayes Valley
# 511900  37.742354 -122.440132  POINT (-122.44013 37.74235)        Glen Park
# 473613  37.794321 -122.413011  POINT (-122.41301 37.79432)         Nob Hill
# 142430  37.740983 -122.418834  POINT (-122.41883 37.74098)   Bernal Heights
# 28348   37.788368 -122.430356  POINT (-122.43036 37.78837)  Pacific Heights
# 458129  37.760499 -122.461770  POINT (-122.46177 37.76050)     Inner Sunset
# 616582  37.806758 -122.412141  POINT (-122.41214 37.80676)      North Beach
# 432904  37.734541 -122.432647  POINT (-122.43265 37.73454)        Glen Park
# 412714  37.751787 -122.405208  POINT (-122.40521 37.75179)          Mission
#
#        Police_district Holiday                    Street
# 326909      TENDERLOIN    None  Charles J. Brenham Place
# 669838        NORTHERN    None            Octavia Street
# 230834       INGLESIDE    None            Rickard Street
# 563308         MISSION    None               23rd Street
# 320591         BAYVIEW    None             Silver Avenue
# 619836       INGLESIDE    None           Gold Mine Drive
# 384070         MISSION    None               16th Street
# 597950      TENDERLOIN    None        Leavenworth Street
# 581150        NORTHERN    None             Fulton Street
# 422853      TENDERLOIN    None               Eddy Street
# 224525         MISSION    None               20th Street
# 187535        NORTHERN    None            Hickory Street
# 511900       INGLESIDE    None           Gold Mine Drive
# 473613         CENTRAL    None         Washington Street
# 142430       INGLESIDE    Both            Eugenia Avenue
# 28348         NORTHERN    None               Pine Street
# 458129            PARK    None            Kirkham Street
# 616582         CENTRAL    None        North Point Street
# 432904       INGLESIDE    None            Chenery Street
# 412714         MISSION    None               25th Street
# -----------------------TIPO--------------------------
# <class 'pandas.core.frame.DataFrame'>
# Obtenido: Bush Street
# -----------------------RESULTADO--------------------------
#           incident_datetime incident_day_of_week  incident_code  \
# 27261   2018-03-10 06:21:00             Saturday           4014
# 445511  2021-06-04 12:00:00               Friday           5041
# 226098  2019-08-06 09:06:00              Tuesday           4134
# 205875  2019-06-16 12:00:00               Sunday           6244
# 72859   2018-07-05 18:46:00             Thursday          26170
# 75634   2018-07-12 16:00:00             Thursday           7023
# 164799  2019-02-24 03:31:00               Sunday          30190
# 361210  2020-09-04 16:44:00               Friday          19057
# 491281  2021-10-14 19:30:00             Thursday           6244
# 649603  2023-01-13 09:05:00               Friday          15161
# 7163    2018-01-18 04:45:00             Thursday           6243
# 81061   2018-07-24 13:43:00              Tuesday          27195
# 81904   2018-07-26 12:09:00             Thursday           7043
# 94356   2018-08-25 08:48:00             Saturday          62050
# 461171  2021-07-19 15:00:00               Monday          71012
# 47912   2018-05-02 00:01:00            Wednesday          65016
# 450539  2021-06-19 09:45:00             Saturday           6244
# 567773  2022-05-28 13:01:00             Saturday          62030
# 112867  2018-10-09 18:30:00              Tuesday           6244
# 427508  2021-04-08 17:00:00             Thursday           5151
#
#                                incident_category    incident_subcategory  \
# 27261                                    ASSAULT      AGGRAVATED ASSAULT
# 445511                                  BURGLARY  BURGLARY - RESIDENTIAL
# 226098                                   ASSAULT          SIMPLE ASSAULT
# 205875                             LARCENY THEFT  LARCENY - FROM VEHICLE
# 72859                        OTHER MISCELLANEOUS                   OTHER
# 75634                        MOTOR VEHICLE THEFT     MOTOR VEHICLE THEFT
# 164799                            OTHER OFFENSES                   OTHER
# 361210                        DISORDERLY CONDUCT            INTIMIDATION
# 491281                             LARCENY THEFT  LARCENY - FROM VEHICLE
# 649603  OFFENCES AGAINST THE FAMILY AND CHILDREN                   OTHER
# 7163                               LARCENY THEFT  LARCENY - FROM VEHICLE
# 81061                        OTHER MISCELLANEOUS                TRESPASS
# 81904                          RECOVERED VEHICLE       RECOVERED VEHICLE
# 94356                                    WARRANT                 WARRANT
# 461171                            OTHER OFFENSES          OTHER OFFENSES
# 47912                        OTHER MISCELLANEOUS                   OTHER
# 450539                             LARCENY THEFT  LARCENY - FROM VEHICLE
# 567773                                   WARRANT                 WARRANT
# 112867                             LARCENY THEFT  LARCENY - FROM VEHICLE
# 427508                                  BURGLARY        BURGLARY - OTHER
#
#                   resolution   latitude   longitude  \
# 27261         Open or Active  37.726980 -122.393570
# 445511        Open or Active  37.750836 -122.441687
# 226098        Open or Active  37.798459 -122.447303
# 205875        Open or Active  37.757167 -122.416720
# 72859   Cite or Arrest Adult  37.784453 -122.408493
# 75634         Open or Active  37.780493 -122.451869
# 164799  Cite or Arrest Adult  37.773635 -122.440922
# 361210  Cite or Arrest Adult  37.784792 -122.464551
# 491281        Open or Active  37.760370 -122.411927
# 649603  Cite or Arrest Adult  37.730708 -122.444298
# 7163          Open or Active  37.768226 -122.420777
# 81061   Cite or Arrest Adult  37.784908 -122.404795
# 81904         Open or Active  37.781498 -122.399802
# 94356   Cite or Arrest Adult  37.760148 -122.420660
# 461171        Open or Active  37.749962 -122.421391
# 47912   Cite or Arrest Adult  37.753968 -122.416413
# 450539        Open or Active  37.765783 -122.469654
# 567773  Cite or Arrest Adult  37.711933 -122.418766
# 112867        Open or Active  37.806658 -122.420560
# 427508        Open or Active  37.791177 -122.400744
#
#                            geometry                    neighborhood  \
# 27261   POINT (-122.39357 37.72698)           Bayview Hunters Point
# 445511  POINT (-122.44169 37.75084)                      Noe Valley
# 226098  POINT (-122.44730 37.79846)                          Marina
# 205875  POINT (-122.41672 37.75717)                         Mission
# 72859   POINT (-122.40849 37.78445)                      Tenderloin
# 75634   POINT (-122.45187 37.78049)               Lone Mountain/USF
# 164799  POINT (-122.44092 37.77364)                    Hayes Valley
# 361210  POINT (-122.46455 37.78479)                  Inner Richmond
# 491281  POINT (-122.41193 37.76037)                         Mission
# 649603  POINT (-122.44430 37.73071)              West of Twin Peaks
# 7163    POINT (-122.42078 37.76823)                         Mission
# 81061   POINT (-122.40480 37.78491)  Financial District/South Beach
# 81904   POINT (-122.39980 37.78150)                 South of Market
# 94356   POINT (-122.42066 37.76015)                         Mission
# 461171  POINT (-122.42139 37.74996)                         Mission
# 47912   POINT (-122.41641 37.75397)                         Mission
# 450539  POINT (-122.46965 37.76578)                    Inner Sunset
# 567773  POINT (-122.41877 37.71193)               Visitacion Valley
# 112867  POINT (-122.42056 37.80666)                    Russian Hill
# 427508  POINT (-122.40074 37.79118)  Financial District/South Beach
#
#        Police_district Holiday               Street
# 27261          BAYVIEW    None     Armstrong Avenue
# 445511         MISSION    None          24th Street
# 226098        NORTHERN    None       Lombard Street
# 205875         MISSION    None          21st Street
# 72859       TENDERLOIN    None  Cyril Magnin Street
# 75634             PARK    None          Anza Street
# 164799            PARK    None          Fell Street
# 361210        RICHMOND    None    California Street
# 491281         MISSION    None          19th Street
# 649603       INGLESIDE    None        Hearst Avenue
# 7163           MISSION    None          14th Street
# 81061       TENDERLOIN    None           4th Street
# 81904         SOUTHERN    None  Tandang Sora Street
# 94356          MISSION    None     Lexington Street
# 461171         MISSION    None      San Jose Avenue
# 47912          MISSION    None          23rd Street
# 450539         TARAVAL    Both          12th Avenue
# 567773       INGLESIDE    None        Santos Street
# 112867         CENTRAL    None          Hyde Street
# 427508         CENTRAL    None          Bush Street
# -----------------------TIPO--------------------------
# <class 'pandas.core.frame.DataFrame'>
# Obtenido: Silver Avenue
# -----------------------RESULTADO--------------------------
#           incident_datetime incident_day_of_week  incident_code  \
# 67502   2018-06-22 11:44:00               Friday          68000
# 11071   2018-01-28 17:15:00               Sunday          64020
# 285735  2020-01-03 18:31:00               Friday          65010
# 163600  2019-02-20 11:00:00            Wednesday           7100
# 593925  2022-08-10 12:00:00            Wednesday           9110
# 620118  2022-10-19 07:14:00            Wednesday          16710
# 187754  2019-04-28 14:42:00               Sunday          64020
# 604893  2022-09-08 18:00:00             Thursday          28100
# 116092  2018-10-17 10:36:00            Wednesday           6372
# 374127  2020-10-18 16:47:00               Sunday           9029
# 307288  2020-03-01 18:00:00               Sunday           6372
# 385315  2020-11-23 11:00:00               Monday          71000
# 331731  2020-05-29 23:36:00               Friday           3072
# 417336  2021-03-04 07:37:00             Thursday          28150
# 53058   2018-05-15 10:30:00              Tuesday          74000
# 76877   2018-07-15 15:01:00               Sunday           6362
# 89479   2018-08-13 04:00:00               Monday           4134
# 572619  2022-06-11 16:00:00             Saturday           6152
# 568445  2022-05-30 12:15:00               Monday           6244
# 277109  2019-12-11 02:39:00            Wednesday           7045
#
#                  incident_category         incident_subcategory  \
# 67502                  FIRE REPORT                  FIRE REPORT
# 11071                 NON-CRIMINAL                        OTHER
# 285735    TRAFFIC VIOLATION ARREST     TRAFFIC VIOLATION ARREST
# 163600                   VANDALISM                    VANDALISM
# 593925  FORGERY AND COUNTERFEITING   FORGERY AND COUNTERFEITING
# 620118                DRUG OFFENSE               DRUG VIOLATION
# 187754                NON-CRIMINAL                        OTHER
# 604893          MALICIOUS MISCHIEF                    VANDALISM
# 116092               LARCENY THEFT        LARCENY THEFT - OTHER
# 374127                       FRAUD                        FRAUD
# 307288               LARCENY THEFT        LARCENY THEFT - OTHER
# 385315               LOST PROPERTY                LOST PROPERTY
# 331731                     ROBBERY              ROBBERY - OTHER
# 417336          MALICIOUS MISCHIEF                    VANDALISM
# 53058               MISSING PERSON                MISSING ADULT
# 76877                LARCENY THEFT  LARCENY THEFT - SHOPLIFTING
# 89479                      ASSAULT               SIMPLE ASSAULT
# 572619               LARCENY THEFT        LARCENY THEFT - OTHER
# 568445               LARCENY THEFT       LARCENY - FROM VEHICLE
# 277109           RECOVERED VEHICLE            RECOVERED VEHICLE
#
#                   resolution   latitude   longitude  \
# 67502         Open or Active  37.733928 -122.416912
# 11071         Open or Active  37.783609 -122.389846
# 285735  Cite or Arrest Adult  37.714308 -122.462602
# 163600        Open or Active  37.759093 -122.438112
# 593925        Open or Active  37.752472 -122.474205
# 620118  Cite or Arrest Adult  37.771795 -122.425322
# 187754        Open or Active  37.723130 -122.435977
# 604893        Open or Active  37.806658 -122.420560
# 116092        Open or Active  37.753225 -122.428695
# 374127        Open or Active  37.780496 -122.432140
# 307288        Open or Active  37.760324 -122.412643
# 385315        Open or Active  37.787568 -122.406590
# 331731  Cite or Arrest Adult  37.753837 -122.418594
# 417336  Cite or Arrest Adult  37.773922 -122.427452
# 53058         Open or Active  37.762269 -122.464042
# 76877         Open or Active  37.788694 -122.405221
# 89479         Open or Active  37.784236 -122.417707
# 572619        Open or Active  37.805185 -122.403436
# 568445        Open or Active  37.805287 -122.423655
# 277109        Open or Active  37.733144 -122.404345
#
#                            geometry                    neighborhood  \
# 67502   POINT (-122.41691 37.73393)                  Bernal Heights
# 11071   POINT (-122.38985 37.78361)  Financial District/South Beach
# 285735  POINT (-122.46260 37.71431)      Oceanview/Merced/Ingleside
# 163600  POINT (-122.43811 37.75909)             Castro/Upper Market
# 593925  POINT (-122.47421 37.75247)                    Inner Sunset
# 620118  POINT (-122.42532 37.77180)                    Hayes Valley
# 187754  POINT (-122.43598 37.72313)                       Excelsior
# 604893  POINT (-122.42056 37.80666)                    Russian Hill
# 116092  POINT (-122.42870 37.75323)                      Noe Valley
# 374127  POINT (-122.43214 37.78050)                Western Addition
# 307288  POINT (-122.41264 37.76032)                         Mission
# 385315  POINT (-122.40659 37.78757)  Financial District/South Beach
# 331731  POINT (-122.41859 37.75384)                         Mission
# 417336  POINT (-122.42745 37.77392)                    Hayes Valley
# 53058   POINT (-122.46404 37.76227)                    Inner Sunset
# 76877   POINT (-122.40522 37.78869)  Financial District/South Beach
# 89479   POINT (-122.41771 37.78424)                      Tenderloin
# 572619  POINT (-122.40344 37.80518)                     North Beach
# 568445  POINT (-122.42366 37.80529)                    Russian Hill
# 277109  POINT (-122.40434 37.73314)           Bayview Hunters Point
#
#        Police_district Holiday              Street
# 67502        INGLESIDE    None       Benton Avenue
# 11071         SOUTHERN    None     Delancey Street
# 285735         TARAVAL    None      Orizaba Avenue
# 163600         MISSION    None         19th Street
# 593925         TARAVAL    None       Ortega Street
# 620118            PARK    None       Waller Street
# 187754       INGLESIDE    None       Persia Avenue
# 604893         CENTRAL    None         Hyde Street
# 116092         MISSION    None         23rd Street
# 374127        NORTHERN    None         Turk Street
# 307288         MISSION    None         19th Street
# 385315         CENTRAL    None    O'Farrell Street
# 331731         MISSION    None         23rd Street
# 417336        NORTHERN    None     Buchanan Street
# 53058             PARK    None        Judah Street
# 76877          CENTRAL    None         Post Street
# 89479       TENDERLOIN    None         Turk Street
# 572619         CENTRAL    None                None
# 568445         CENTRAL    Both  North Point Street
# 277109         BAYVIEW    None       Silver Avenue
# -----------------------TIPO--------------------------
# <class 'pandas.core.frame.DataFrame'>
